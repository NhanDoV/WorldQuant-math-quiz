# %% [markdown]
# ### 1.

# %%
import time
from solution import *

simulation_generated_nums(5)
# Out:
# ...
# Step      adding / subtracting ?? to the set generated before                            Generated set
# -----           ----------------------------------------          ------------------------------------------------------------
#   0                                0                              -1,0,1
#   1                                3                              -4,-3,-2,2,3,4
#   2                                9                              -13,-12,-11,-7,-6,-5,5,6,7,11,12,13
#   3                                27                             -40,-39,-38,-34,-33,-32,-22,-21,-20,-16,-15,-14,14,15,16,20,21,22,32,33,34,38,39,40
#   4                                81                             -121,-120,-119,-115,-114,-113,-103,-102,-101,-97,-96,-95,-67,-66,-65,-61,-60,-59,-49,-48,-47,-43,-42,-41,41,42,43,47,48,49,59,60,61,65,66,67,95,96,97,101,102,103,113,114,115,119,120,121
# ...
